# %% [markdown]
# # X-Ray Image Classification

# %% [markdown]
# ## Import Modules and Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import re
import os 
import urllib.request
import random
import pickle
import boto3
from PIL import Image
from glob import glob
from copy import deepcopy

#Sci-Kit Learn Modules
from skimage import color
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_curve, roc_auc_score, f1_score, accuracy_score 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix 
from sklearn.metrics import plot_precision_recall_curve, plot_roc_curve

#Tensorflow Modules
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.compat.v1 import set_random_seed

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from tensorflow.keras import models, metrics 
from tensorflow.keras.applications import imagenet_utils, ResNet50V2, ResNet101V2, ResNet152V2, VGG19 
from tensorflow.keras.models import Sequential, Model, load_model, 
from tensorflow.keras.layers import Conv2D, SeparableConv2D, MaxPool2D, MaxPooling2D
from tensorflow.keras.layers import Activation, BatchNormalization, UpSampling2D, Dropout, Flatten, Dense 
from tensorflow.keras.layers import Input, ReLU, LeakyReLU, Conv2DTranspose, AveragePooling2D, Concatenate

from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.initializers import he_normal, he_uniform, glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adamax
from tensorflow.keras.metrics import Recall, Precision, Accuracy, AUC

# %%
import time
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# ## Read in Image Data

# %%
# Directory path
train_data_dir = '../xrays/train/'
test_data_dir = '../xrays/test'
val_data_dir = '../xrays/val'

# Get all the data in the directory xrays/train, and reshape them
train_generator = ImageDataGenerator(rescale = 1.0/255.,
                                     rotation_range = 3,
                                     width_shift_range=0.05,
                                     height_shift_range = 0.05,
                                     shear_range = 0.05,
                                     zoom_range = 0.05,
                                     ).flow_from_directory(train_data_dir, 
                                                           target_size=(256, 256),
                                                           class_mode='binary',
                                                           color_mode='grayscale',
                                                           seed=42)

# Get all the data in the directory xrays/test, and reshape them
test_generator = ImageDataGenerator(rescale = 1.0/255.,
                                   ).flow_from_directory(test_data_dir, 
                                                         target_size=(256, 256),
                                                         class_mode='binary',
                                                         color_mode='grayscale',
                                                         shuffle = False)


# Get all the data in the directory xrays/val, and reshape them
val_generator = ImageDataGenerator(rescale = 1.0/255.,
                                   ).flow_from_directory(val_data_dir, 
                                                         target_size=(256, 256),
                                                         class_mode='binary',
                                                         color_mode='grayscale',
                                                         shuffle=False)


# Create the datasets
X_train, y_train = next(train_generator)
X_test, y_test = next(test_generator)
X_val, y_val = next(val_generator)


# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=42)
# Out:
# Found 4616 images belonging to 2 classes.
# Found 640 images belonging to 2 classes.
# Found 600 images belonging to 2 classes.

# %% [markdown]
# ## Exploratory Data Analsis

# %% [markdown]
# ### Visualizing Images in Dataset

# %% [markdown]
# **Previewing a few images from dataset**

# %%
# Images and Labes from Training Set

plt.style.use('default')
fig=plt.figure(figsize=(20, 10))
columns = 6; rows = 4
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    for X_batch, Y_batch in train_generator:
        image = X_batch[0]        
        dic = {0:"NORMAL", 1:"PNEUMONIA"}
        plt.title(dic.get(Y_batch[0]))
        plt.axis("off")
        plt.imshow(array_to_img(X_train[i]), cmap=plt.cm.gray)
        plt.colorbar()
        fig.add_subplot
        break

# %% [markdown]
# The x-ray images of patients with pneumonia appear cloudier around the lung area.

# %%
#Images and Labels from Validation Set

plt.style.use('default')
fig=plt.figure(figsize=(20, 10))
columns = 6; rows = 4
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    for X_batch, Y_batch in val_generator:
        image = X_batch[0]        
        dic = {0:"NORMAL", 1:"PNEUMONIA"}
        plt.title(dic.get(Y_batch[0]))
        plt.axis("off")
        plt.imshow(array_to_img(X_train[i]), cmap=plt.cm.gray)
        plt.colorbar()
        fig.add_subplot
        break

# %%
train_generator.filepaths
# Out:
# ['../xrays/train/NORMAL/IM-0115-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0117-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0119-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0122-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0125-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0127-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0128-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0129-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0131-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0133-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0135-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0137-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0140-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0141-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0143-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0145-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0147-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0149-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0151-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0152-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0154-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0156-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0158-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0160-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0162-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0164-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0166-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0168-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0170-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0172-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0176-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0177-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0178-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0180-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0182-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0183-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0185-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0187-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0189-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0191-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0193-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0195-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0199-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0201-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0203-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0205-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0206-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0207-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0209-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0210-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0211-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0213-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0214-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0215-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0216-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0217-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0218-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0219-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0220-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0221-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0222-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0223-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0224-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0225-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0226-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0227-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0228-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0229-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0230-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0231-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0234-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0235-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0236-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0237-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0238-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0239-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0240-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0241-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0242-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0243-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0244-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0245-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0248-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0249-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0250-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0251-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0253-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0255-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0256-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0257-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0261-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0262-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0264-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0265-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0266-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0268-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0269-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0270-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0272-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0273-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0274-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0275-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0276-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0277-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0278-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0279-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0280-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0282-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0283-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0285-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0286-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0288-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0289-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0290-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0291-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0292-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0293-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0294-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0295-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0297-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0298-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0299-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0300-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0301-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0302-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0303-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0304-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0305-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0306-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0307-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0308-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0309-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0311-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0312-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0313-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0314-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0315-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0316-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0317-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0318-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0319-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0320-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0323-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0324-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0325-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0326-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0327-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0329-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0330-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0331-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0332-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0333-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0335-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0337-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0338-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0339-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0340-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0341-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0343-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0345-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0346-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0347-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0348-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0349-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0350-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0351-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0353-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0354-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0355-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0356-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0357-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0358-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0359-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0361-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0362-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0363-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0364-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0365-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0367-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0368-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0369-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0370-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0371-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0372-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0374-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0375-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0377-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0379-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0381-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0382-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0383-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0384-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0385-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0386-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0387-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0388-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0389-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0391-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0392-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0393-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0394-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0395-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0399-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0400-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0401-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0403-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0404-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0405-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0408-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0409-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0410-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0411-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0413-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0414-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0416-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0417-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0419-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0420-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0421-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0423-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0424-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0425-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0427-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0428-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0429-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0429-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0429-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0430-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0431-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0432-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0433-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0434-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0435-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0435-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0437-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0437-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0437-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0438-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0439-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0439-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0439-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0440-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0441-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0442-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0444-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0445-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0446-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0447-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0448-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0449-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0450-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0451-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0452-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0453-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0453-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0455-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0456-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0457-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0458-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0459-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0460-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0461-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0463-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0464-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0465-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0466-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0467-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0467-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0467-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0469-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0471-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0472-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0473-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0474-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0475-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0476-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0477-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0478-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0479-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0480-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0481-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0482-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0483-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0484-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0485-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0486-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0487-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0488-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0489-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0490-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0491-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0491-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0491-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0492-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0493-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0494-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0495-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0496-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0497-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0497-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0497-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0499-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0499-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0499-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0500-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0501-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0501-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0501-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0502-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0503-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0504-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0505-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0505-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0505-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0506-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0507-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0508-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0509-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0509-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0509-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0510-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0511-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0511-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0511-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0512-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0513-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0514-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0515-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0516-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0517-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0517-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0519-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0519-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0519-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0520-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0521-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0522-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0523-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0523-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0523-0001-0003.jpeg',
#  '../xrays/train/NORMAL/IM-0523-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0524-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0525-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0525-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0525-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0526-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0527-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0528-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0529-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0530-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0531-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0531-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0532-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0533-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0533-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0533-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0534-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0535-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0536-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0537-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0538-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0539-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0539-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0539-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0540-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0541-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0542-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0543-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0543-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0544-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0545-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0545-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0545-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0546-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0547-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0548-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0549-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0549-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0549-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0551-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0551-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0551-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0552-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0553-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0553-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0553-0001-0003.jpeg',
#  '../xrays/train/NORMAL/IM-0553-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0554-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0555-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0555-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0555-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0556-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0557-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0559-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0560-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0561-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0562-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0563-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0564-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0565-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0566-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0568-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0569-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0570-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0571-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0574-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0575-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0577-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0578-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0579-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0580-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0581-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0582-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0583-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0584-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0586-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0588-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0590-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0591-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0592-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0593-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0595-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0596-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0598-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0599-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0600-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0601-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0602-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0604-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0605-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0606-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0607-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0608-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0608-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0608-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0609-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0612-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0612-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0612-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0613-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0614-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0615-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0616-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0617-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0618-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0618-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0618-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0619-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0620-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0620-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0620-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0621-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0622-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0622-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0622-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0623-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0624-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0624-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0625-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0626-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0626-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0627-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0628-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0629-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0629-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0629-0001-0003.jpeg',
#  '../xrays/train/NORMAL/IM-0629-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0630-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0631-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0631-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0631-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0632-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0633-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0634-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0635-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0636-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0637-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0640-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0640-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0640-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0641-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0642-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0643-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0644-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0644-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0644-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0645-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0646-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0647-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0648-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0649-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0650-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0650-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0650-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0651-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0652-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0652-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0654-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0655-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0656-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0656-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0656-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0657-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0658-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0659-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0660-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0660-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0660-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0661-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0662-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0663-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0664-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0665-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0666-0001-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0666-0001-0002.jpeg',
#  '../xrays/train/NORMAL/IM-0666-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0667-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0668-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0669-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0670-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0671-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0672-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0673-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0674-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0675-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0676-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0677-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0678-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0679-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0680-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0681-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0682-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0683-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0684-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0685-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0686-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0687-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0688-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0689-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0691-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0692-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0693-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0694-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0695-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0696-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0697-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0698-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0700-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0701-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0702-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0703-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0704-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0705-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0706-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0707-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0709-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0710-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0711-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0712-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0713-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0714-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0715-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0716-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0717-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0718-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0719-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0721-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0722-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0724-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0727-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0728-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0729-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0730-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0732-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0733-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0734-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0735-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0736-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0737-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0738-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0739-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0740-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0741-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0742-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0746-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0747-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0748-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0750-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0751-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0752-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0753-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0754-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0755-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0757-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0761-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0764-0001.jpeg',
#  '../xrays/train/NORMAL/IM-0766-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0383-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0384-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0385-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0386-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0388-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0389-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0390-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0391-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0392-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0393-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0394-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0395-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0395-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0395-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0396-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0397-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0399-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0401-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0402-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0403-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0404-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0406-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0407-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0408-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0409-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0410-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0412-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0413-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0414-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0415-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0416-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0416-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0416-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0417-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0418-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0419-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0421-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0423-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0424-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0425-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0427-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0428-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0429-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0433-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0435-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0437-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0439-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0440-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0441-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0443-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0445-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0447-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0448-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0449-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0450-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0451-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0452-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0453-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0454-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0455-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0456-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0458-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0460-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0462-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0463-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0464-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0465-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0466-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0468-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0472-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0473-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0474-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0475-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0476-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0478-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0479-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0480-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0481-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0482-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0485-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0486-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0487-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0488-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0489-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0490-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0491-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0493-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0496-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0497-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0499-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0500-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0501-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0502-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0503-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0506-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0507-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0508-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0509-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0511-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0512-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0513-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0515-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0516-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0517-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0518-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0520-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0521-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0522-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0523-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0525-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0526-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0528-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0529-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0530-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0531-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0533-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0535-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0535-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0536-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0537-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0539-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0540-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0541-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0543-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0545-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0547-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0550-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0551-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0552-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0553-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0554-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0555-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0555-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0555-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0557-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0558-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0559-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0561-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0563-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0564-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0566-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0567-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0568-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0569-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0571-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0572-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0573-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0575-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0576-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0577-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0578-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0579-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0580-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0582-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0583-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0585-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0587-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0587-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0587-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0588-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0589-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0592-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0594-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0595-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0596-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0599-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0600-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0601-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0602-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0603-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0604-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0609-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0611-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0616-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0617-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0618-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0619-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0620-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0621-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0622-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0623-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0626-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0627-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0629-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0630-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0633-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0634-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0635-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0636-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0637-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0640-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0641-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0642-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0643-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0645-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0647-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0648-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0649-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0650-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0651-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0651-0004.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0652-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0653-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0654-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0655-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0657-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0659-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0660-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0661-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0662-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0663-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0664-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0665-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0666-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0667-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0668-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0669-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0671-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0672-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0673-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0675-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0678-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0680-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0682-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0683-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0684-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0686-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0687-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0689-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0690-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0692-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0693-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0694-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0695-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0696-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0698-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0699-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0700-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0702-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0705-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0707-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0718-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0719-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0723-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0725-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0727-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0730-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0736-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0741-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0744-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0746-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0749-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0753-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0757-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0765-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0771-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0772-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0774-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0775-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0776-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0777-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0780-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0781-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0790-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0793-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0796-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0797-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0798-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0799-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0803-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0804-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0806-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0807-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0808-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0809-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0810-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0811-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0812-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0814-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0815-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0816-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0818-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0818-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0819-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0820-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0821-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0822-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0824-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0825-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0826-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0827-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0828-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0829-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0830-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0831-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0832-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0832-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0832-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0833-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0834-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0836-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0837-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0838-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0839-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0840-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0841-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0842-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0843-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0845-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0846-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0847-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0848-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0849-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0851-0001-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0851-0001-0002.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0851-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0852-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0853-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0854-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0855-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0856-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0857-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0858-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0859-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0860-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0862-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0863-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0865-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0866-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0867-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0868-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0869-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0870-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0871-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0872-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0873-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0874-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0875-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0876-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0877-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0879-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0880-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0881-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0882-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0885-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0886-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0887-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0888-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0890-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0892-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0893-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0894-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0895-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0896-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0897-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0898-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0899-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0900-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0903-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0904-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0905-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0906-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0907-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0908-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0909-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0910-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0911-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0912-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0913-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0914-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0915-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0917-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0918-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0919-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0922-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0923-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0924-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0925-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0926-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0927-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0929-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0930-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0931-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0932-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0933-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0934-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0935-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0936-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0937-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0939-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0941-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0942-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0944-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0945-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0946-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0947-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0948-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0949-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0950-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0951-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0952-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0954-0001.jpeg',
#  '../xrays/train/NORMAL/NORMAL2-IM-0955-0001.jpeg',
#  ...]

# %%
# norm_files_path = [os.path.relpath(x) for x in os.listdir("../xrays/val/NORMAL/")]
# norm_files_path

# %%
fig, ax = plt.subplots(4, 2, figsize=(20, 20))


for row, file_path in enumerate(train_generator.filepaths[:4]):
    image = plt.imread(file_path)
    ax[row, 0].imshow(image)
    ax[row, 1].hist(image.ravel(), 256, [0,256])
    ax[row, 0].axis('off')
    if row == 0:
        ax[row, 0].set_title('Images')
        ax[row, 1].set_title('Histograms')
fig.suptitle('..', size=16)
plt.show()

# %% [markdown]
# ### Visualizing Class Counts

# %%
train_generator.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
train_class = train_generator.classes
test_class = test_generator.classes
val_class = val_generator.classes

# %%
#Class Count in Training, Testing, and Validation sets

a = []
b = []
c = []

[a.append("NORMAL") if x == 0 else a.append("PNEUMONIA") for x in train_class]
[b.append("NORMAL") if x == 0 else b.append("PNEUMONIA") for x in test_class]
[c.append("NORMAL") if  x == 0 else c.append("PNEUMONIA") for x in val_class]

sns.countplot(a)
plt.title("Training Set Class Count")
plt.show()

sns.countplot(b)
plt.title("Testing Set Class Count")
plt.show()

sns.countplot(c)
plt.title("Validation Set Class Count")
plt.show()

# %% [markdown]
# The class imbalance in the training set is quite clear. In order to create a more balanced training set, we adjusted the class weights in our models.

# %% [markdown]
# ## Dealing with Class Imbalance in Training Set

# %%
from sklearn.utils import class_weight
class_weights = dict(zip(np.unique(y_train), class_weight.compute_class_weight(class_weight = 'balanced',
                                                                               classes = np.unique(y_train),
                                                                               y = y_train)))

# %%
class_weights
# Out:
# {0.0: 1.7777777777777777, 1.0: 0.6956521739130435}

# %% [markdown]
# These are the adjusted weights for our "0" or Normal class, and our "1" or Pneumonia class. As you can see, the weights applied to our Normal class is greater to account for the class imbalance.

# %% [markdown]
# ## Modeling Process

# %% [markdown]
# ## Model Q

# %%
modelq = models.Sequential()

modelq.add(Conv2D(32, (3, 3), kernel_initializer=he_uniform(), activation='relu', input_shape=(256, 256, 1)))
modelq.add(MaxPooling2D((2, 2)))

modelq.add(Conv2D(64, (3, 3), kernel_initializer=he_uniform(), activation='relu'))
modelq.add(MaxPooling2D((2, 2)))

modelq.add(Conv2D(128, (3, 3), kernel_initializer=he_uniform(), activation='relu'))
modelq.add(MaxPooling2D((2, 2)))

modelq.add(Conv2D(128, (3, 3), kernel_initializer=he_uniform(), activation='relu'))
modelq.add(MaxPooling2D((2, 2)))

modelq.add(Flatten())
modelq.add(Dropout(0.5))
modelq.add(Dense(512, kernel_initializer=he_uniform(), activation='relu'))
modelq.add(Dense(1, activation='sigmoid'))

modelq.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 13,086,337
# Trainable params: 13,086,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile model
compileparams = modelq.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-4), metrics=[Recall(), Precision(),'acc'])

# %%
from keras_tqdm import TQDMNotebookCallback
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

callbacks = [EarlyStopping(monitor='val_loss', patience=10),
            ModelCheckpoint(filepath='best_model.h5', monitor='val_loss', save_best_only=True),TQDMNotebookCallback()]

# %%
#Fit the model to Training Set and Validate on Validation set
history_q = modelq.fit(train_generator, 
                    validation_data=(val_generator),
                    steps_per_epoch= 144,
                    epochs=5,
                    class_weight = class_weights,
#                        verbose=2,
#                        callbacks=callbacks
                    )
# Out:
# Epoch 1/5
# 144/144 [==============================] - 928s 6s/step - loss: 0.4855 - recall: 0.8713 - precision: 0.9156 - acc: 0.8381 - val_loss: 0.1067 - val_recall: 0.9933 - val_precision: 0.9430 - val_acc: 0.9667
# Epoch 2/5
# 144/144 [==============================] - 603s 4s/step - loss: 0.1560 - recall: 0.9442 - precision: 0.9804 - acc: 0.9422 - val_loss: 0.1474 - val_recall: 0.9967 - val_precision: 0.8979 - val_acc: 0.9417
# Epoch 3/5
# 144/144 [==============================] - 610s 4s/step - loss: 0.1301 - recall: 0.9524 - precision: 0.9851 - acc: 0.9520 - val_loss: 0.0662 - val_recall: 0.9967 - val_precision: 0.9614 - val_acc: 0.9783
# Epoch 4/5
# 144/144 [==============================] - 655s 5s/step - loss: 0.1330 - recall: 0.9518 - precision: 0.9846 - acc: 0.9511 - val_loss: 0.2333 - val_recall: 1.0000 - val_precision: 0.8287 - val_acc: 0.8967
# Epoch 5/5
# 144/144 [==============================] - 483s 3s/step - loss: 0.1307 - recall: 0.9507 - precision: 0.9837 - acc: 0.9496 - val_loss: 0.0493 - val_recall: 0.9933 - val_precision: 0.9868 - val_acc: 0.9900

# %%
# save model to JSON
modelq_json = modelq.to_json()
with open("modelq.json", "w") as json_file:
    json_file.write(modelq_json)

# save weights to HDF5
modelq.save_weights("model_q_weights.h5")
print("Saved model to disk")

modelq.save('model_q.h5')  # creates a HDF5 file 'my_model.h5'
# del modelq  # deletes the existing model

# %% [markdown]
# ### Plotting Validation Accuracy and Loss for Model Q

# %%
acc = history_q.history['acc']
val_acc = history_q.history['val_acc']
loss = history_q.history['loss']
val_loss = history_q.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix for Model Q

# %% [markdown]
# **Predict on test set**

# %%
y_pred_q = modelq.predict(test_generator) > 0.5
y_true = test_generator.classes

# %%
cm_q = confusion_matrix(test_generator.classes, y_pred_q)
print(cm_q)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_q, display_labels=["Normal", "Pneumonia"])

disp.plot(cmap='Blues')
plt.show()
# Out:
# [[161  81]
#  [ 11 387]]

# %% [markdown]
# ## Viewing Missed Casses

# %%
missed_class = [idx for idx, y in enumerate(y_true) if y != y_pred_q[idx]]

# %%
lst = []
i = 0
while i < 350:
    lst.extend(next(test_generator))
    i += 1
# Out:
# 700

# %%
missed_xray = [x for idx, x in enumerate(lst) if idx in missed_class]

# %% [markdown]
# Example 1

# %%
print(missed_xray[1][5])
array_to_img(missed_xray[0][5])
# Out:
# 0.0
# <PIL.Image.Image image mode=L size=256x256 at 0x7FF657283D30>

# %%
y_pred_q[28]
# Out:
# array([ True])

# %% [markdown]
# Example 2

# %%
print(missed_xray[1][30])
array_to_img(missed_xray[0][30])
# Out:
# 1.0
# <PIL.Image.Image image mode=L size=256x256 at 0x7FF727580358>

# %%
y_pred_q[30]
# Out:
# array([False])

# %% [markdown]
# ### Evaluating Model Q's Performance on Test Set

# %%
score_q = modelq.evaluate(test_generator, verbose=1)
score_q
# Out:
# 20/20 [==============================] - 20s 950ms/step - loss: 0.4072 - recall: 0.9724 - precision: 0.8269 - acc: 0.8562
# [0.40720391273498535,
#  0.9723618030548096,
#  0.8269230723381042,
#  0.856249988079071]

# %% [markdown]
# ROC Curve

# %%
# y_val_prob = modelq.predict_proba(X_val)

# fpr, tpr, thresholds = roc_curve (y_val , y_val_prob)

# def plot_roc_curve(fpr,tpr): 
#     plt.plot(fpr,tpr)  
#     plt.xlabel('False Positive Rate') 
#     plt.ylabel('True Positive Rate') 
#     plt.show()    

    
# plot_roc_curve(fpr,tpr)

# %%
# #AUC Score 
# auc_score=roc_auc_score(y_val, y_val_prob) 
# auc_score

# %% [markdown]
# ## Model R - Minor Changes

# %%
modelr = models.Sequential()

modelr.add(Conv2D(32, (7, 7), kernel_initializer=he_uniform(), kernel_regularizer=l2(), padding = "same", activation='relu', input_shape=(256, 256, 1)))
modelr.add(MaxPooling2D((2, 2)))

modelr.add(Conv2D(64, (3, 3), kernel_initializer=he_uniform(), kernel_regularizer=l2(), padding = "same", activation='relu'))
modelr.add(MaxPooling2D((2, 2)))

modelr.add(Conv2D(128, (3, 3), kernel_initializer=he_uniform(), kernel_regularizer=l2(), padding = "same", activation='relu'))
modelr.add(MaxPooling2D((2, 2)))

modelr.add(Conv2D(128, (3, 3), kernel_initializer=he_uniform(), kernel_regularizer=l2(), padding = "same", activation='relu'))
modelr.add(MaxPooling2D((2, 2)))

modelr.add(Conv2D(256, (3, 3), kernel_initializer=he_uniform(), kernel_regularizer=l2(), padding = "same", activation='relu'))
modelr.add(MaxPooling2D((2, 2)))

modelr.add(Conv2D(256, (3, 3), kernel_initializer=he_uniform(), kernel_regularizer=l2(), padding = "same", activation='relu'))
modelr.add(MaxPooling2D((2, 2)))

modelr.add(Flatten())
modelr.add(Dropout(0.5))
modelr.add(Dense(512, kernel_initializer=he_uniform(), activation='relu'))
modelr.add(Dense(1, activation='sigmoid'))

modelr.summary()

# %%
#Compile model
modelr.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-4), metrics=[Recall(), Precision(),'acc'])

# %%
#Fit the model to Training Set and Validate on Validation set
history_r = modelr.fit(train_generator, 
                    validation_data=(val_generator),
                    steps_per_epoch= 144,
                    epochs=50,
                    class_weight = class_weights
                    )

# %% [markdown]
# ### Plotting Validation Accuracy and Loss for Model R

# %%
acc = history_r.history['acc']
val_acc = history_r.history['val_acc']
loss = history_r.history['loss']
val_loss = history_r.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix for Model R

# %% [markdown]
# **Predict on test set**

# %%
y_pred_r = modelr.predict(test_generator) > 0.5
y_true = test_generator.classes

# %%
#Confusion Matrix
cm_r = confusion_matrix(y_true, y_pred_r)
print(cm_r)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot(cmap='Blues')
plt.show()

# %%
# print('Confusion Matrix\n')
# matrix = confusion_matrix(y_true, y_pred_r)
# print(matrix)


# disp = ConfusionMatrixDisplay(confusion_matrix=matrix)

# disp.plot(cmap='Blues')
# plt.show()

# %% [markdown]
# ### Evaluating Model R's Performance on Test Set

# %%
score_r = modelr.evaluate(test_generator, verbose=1)
score_r

# %% [markdown]
# ## Model T

# %%
modelt = models.Sequential()


modelt.add(Conv2D(16, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same',input_shape=(256, 256, 1)))
modelt.add(Conv2D(16, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(MaxPool2D((2, 2)))


modelt.add(SeparableConv2D(32, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(SeparableConv2D(32, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(BatchNormalization())
modelt.add(MaxPool2D((2, 2)))


modelt.add(SeparableConv2D(64, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(SeparableConv2D(64, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(BatchNormalization())
modelt.add(MaxPool2D((2, 2)))


modelt.add(SeparableConv2D(128, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(SeparableConv2D(128, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(BatchNormalization())
modelt.add(MaxPool2D((2, 2)))
modelt.add(Dropout(rate=0.2))


modelt.add(SeparableConv2D(256, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(SeparableConv2D(256, (3, 3), kernel_initializer=he_uniform(), activation='relu', padding='same'))
modelt.add(BatchNormalization())
modelt.add(MaxPool2D((2, 2)))
modelt.add(Dropout(0.2))


modelt.add(Flatten())
modelt.add(Dense(512, kernel_initializer=he_uniform(), activation='relu'))
modelt.add(Dropout(0.5))
modelt.add(Dense(128, kernel_initializer=he_uniform(), activation='relu'))
modelt.add(Dropout(0.5))
modelt.add(Dense(64, kernel_initializer=he_uniform(), activation='relu'))
modelt.add(Dropout(0.3))

modelt.add(Dense(1, activation='sigmoid'))
   
    
modelt.summary()

# %%
#Compile model 
modelt.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-4), metrics=[Recall(), Precision(),'acc'])

#Fit the model to Training Set and Validate on Validation set
hist = modelt.fit(train_generator, 
                    validation_data=(val_generator),
                    steps_per_epoch= 144,
                    epochs=50,
                    class_weight = class_weights
                    )

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['acc', 'loss']):
    ax[i].plot(hist.history[met])
    ax[i].plot(hist.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### Confusion Matrix for Model T

# %%
y_pred_t = modelt.predict(test_generator) > 0.5
y_true = test_generator.classes

print('Confusion Matrix\n')
cm_t = confusion_matrix(y_true, y_pred_t)
print(cm_t)


disp = ConfusionMatrixDisplay(confusion_matrix=cm_t)

disp.plot(cmap='Blues')
plt.show()

# %% [markdown]
# ### Evaluating Model T's Performance on Test Set

# %%
score_t = modelt.evaluate(test_generator, verbose=1)
score_t

# %% [markdown]
# ## Model Z

# %%
modelz = models.Sequential()

modelz.add(Conv2D(32, (7,7), kernel_initializer=he_uniform(), kernel_regularizer=l2(), activation='relu', input_shape=(256, 256, 1)))
modelz.add(MaxPooling2D(2,2))

modelz.add(Conv2D(32, (3,3), kernel_initializer=he_uniform(), kernel_regularizer=l2(), activation='relu'))
modelz.add(MaxPooling2D(2,2))

modelz.add(Conv2D(128,(3,3), kernel_initializer=he_uniform(), activation='relu'))
modelz.add(MaxPooling2D(2,2))

modelz.add(Conv2D(64,(3,3), kernel_initializer=he_uniform(), activation='relu'))
modelz.add(MaxPooling2D(2,2))

modelz.add(Conv2D(128,(3,3), kernel_initializer=he_uniform(), activation='relu'))
modelz.add(MaxPooling2D(2,2))

modelz.add(Conv2D(128,(3,3), kernel_initializer=he_uniform(), activation='relu'))
modelz.add(MaxPooling2D(2,2))
    

modelz.add(Flatten())
modelz.add(Dense(128, kernel_initializer=he_uniform(), activation='relu'))
modelz.add(Dropout(0.5))

modelz.add(Dense(1, activation='sigmoid'))

modelz.summary()

# %%
#Compile model 
modelz.compile(Adam(lr=1e-6),loss = 'binary_crossentropy', metrics=[Recall(), Precision(),'acc'])

# %%
#Fit the model to Training Set and Validate on Validation set
history_z = modelz.fit(train_generator,
                    validation_data =(val_generator),
                    epochs = 17,
                    steps_per_epoch=144
                    class_weight=class_weights,
                    verbose=2)

# %% [markdown]
# ### Plotting Validation Accuracy and Loss for Model Z

# %%
# Plotting Validation Accuracy and Loss for Model Z 
acc = history_z.history['acc']
val_acc = history_z.history['val_acc']
loss = history_z.history['loss']
val_loss = history_z.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Confustion Matrix for Model Z

# %%
y_pred_z = modelz.predict(test_generator) > 0.5
y_true = test_generator.classes

print('Confusion Matrix\n')
cm_z = confusion_matrix(y_true, y_pred_z)
print(cm_z)


disp = ConfusionMatrixDisplay(confusion_matrix=cm_z)

disp.plot(cmap='Blues')
plt.show()

# %% [markdown]
# ### Evaluating Model Z's Performance on Test Set

# %%
score_z = modelz.evaluate(test_generator, verbose=0)
score_z

# %% [markdown]
# ## Model Alex_net

# %%
# Create callbacks for our model

# Create checkpoint callback
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('model_alex_net.h5') 

# Create Custom callback
class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > 0.93 and logs.get('val_accuracy') > 0.93) and (logs.get('loss')<= 0.3 and logs.get('val_loss') <= 0.3):
            if logs.get('accuracy') <= logs.get('val_accuracy'):
                self.model.stop_training = True
            else:
                self.model.stop_training = False
#             if(logs.get('accuracy') > 0.94 and logs.get('val_accuracy') > 0.94) and (logs.get('loss')<= 0.3 and logs.get('val_loss') <= 0.3):

custom_cb = CustomCallback()

# %%
# Define alexNet model


model_alex_net = tf.keras.models.Sequential([
     # 1st conv layer                                        
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(256,256,1),
                           padding='valid'),
    tf.keras.layers.BatchNormalization(),
    # Max pooling
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2), padding='valid'),
    
    # # Dropout to prevent overfit
    # tf.keras.layers.Dropout(0.5),

    # 2nd conv layer
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),

    # Max pooling
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2), padding='valid'),

    # # Dropout to prevent overfit
    # tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    # 3rd conv layer
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    # 4th Conv layer
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    # 5th Conv layer
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    # Max Pooling
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    # Dropout to prevent overfit
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4096, activation='relu'),
    # # Dropout to prevent overfit
    # tf.keras.layers.Dropout(0.3),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    # Dropout to prevent overfit
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
# Look at summary of our model
model_alex_net.summary()

# %%
model_alex_net.compile(loss='binary_crossentropy', optimizer =Adam(lr=1e-6), metrics=['accuracy', Recall()])

# %%
hist = model_alex_net.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs = 32,
    class_weight=class_weights,
    callbacks=[custom_cb, checkpoint_cb]
)

# %%
print('Loss of the model is - ', model_alex_net.evaluate(X_val, y_val)[0])
print('Accuracy of the model is - ', model_alex_net.evaluate(X_val, y_val)[1]*100, '%')

# %%
predict = model_alex_net.predict_classes(X_test)
predict = predict.reshape(1, -1)[0]
predict

# %%
predict_test = model_alex_net.predict_classes(X_test)
predict_test = predict.reshape(1, -1)[0]
predict_test

# %%
print(classification_report(y_val, predict, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))

# %%
# print(classification_report(y_test, predict_test, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))

# %%
print('Confusion Matrix\n')
matrix = confusion_matrix(y_test, predict)
print(matrix)

disp = ConfusionMatrixDisplay(confusion_matrix=matrix)

disp.plot(cmap='Blues')
plt.show()

# %%
correct = np.nonzero(predict == y_val)[0]
incorrect = np.nonzero(predict != y_val)[0]
print(len(correct), len(incorrect))

# %%
i = 0
for c in correct[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_val[c], cmap="gray", interpolation='none')
    plt.title("Predicted Class {}\nActual Class {}".format(predict[c], y_val[c]))
    plt.tight_layout()
    i += 1

# %%
i = 0
for c in incorrect[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_val[c], cmap="gray", interpolation='none')
    plt.title("Predicted Class {}\nActual Class {}".format(predict[c], y_val[c]))
    plt.tight_layout()
